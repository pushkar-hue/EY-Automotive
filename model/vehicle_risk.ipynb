# %%
import pandas as pd

# %%
df=pd.read_csv('time_series_vehicle_failure_dataset.csv')

# %%
df.head(5)
# Out:
#              timestamp vehicle_id    car_name  mileage_km  engine_temp  \
# 0  2025-01-01 00:00:00       V001  Tata Nexon       39440        92.09
# 1  2025-01-01 12:00:00       V001  Tata Nexon       39470        91.96
# 2  2025-01-02 00:00:00       V001  Tata Nexon       39500        91.76
# 3  2025-01-02 12:00:00       V001  Tata Nexon       39530        92.26
# 4  2025-01-03 00:00:00       V001  Tata Nexon       39560        92.03
#
#    oil_pressure  battery_voltage  brake_pad_thickness  tire_pressure   rpm  \
# 0         34.11            12.30                 9.13          33.72  1601
# 1         33.41            12.28                 9.12          33.80  3796
# 2         33.24            12.29                 9.10          33.96   874
# 3         33.15            12.30                 9.06          33.91  3246
# 4         32.96            12.30                 9.02          33.89  3601
#
#    speed_kmph  failure
# 0          21        0
# 1         109        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            1000 non-null   object
#  1   vehicle_id           1000 non-null   object
#  2   car_name             1000 non-null   object
#  3   mileage_km           1000 non-null   int64
#  4   engine_temp          1000 non-null   float64
#  5   oil_pressure         1000 non-null   float64
#  6   battery_voltage      1000 non-null   float64
#  7   brake_pad_thickness  1000 non-null   float64
#  8   tire_pressure        1000 non-null   float64
#  9   rpm                  1000 non-null   int64
#  10  speed_kmph           1000 non-null   int64
#  11  failure              1000 non-null   int64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 93.9+ KB

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.isnull().sum()
# Out:
# timestamp              0
# vehicle_id             0
# car_name               0
# mileage_km             0
# engine_temp            0
# oil_pressure           0
# battery_voltage        0
# brake_pad_thickness    0
# tire_pressure          0
# rpm                    0
# speed_kmph             0
# failure                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
feature_cols = [
    'mileage_km', 'engine_temp', 'oil_pressure', 'battery_voltage',
    'brake_pad_thickness', 'tire_pressure', 'rpm', 'speed_kmph'
]
target_col='failure'

# %%
x=df[feature_cols]
y=df[target_col]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=False,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
print(f"Total data shape: {x.shape}")
print(f"Train data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
# Out:
# Total data shape: (1000, 8)
# Train data shape: (800, 8)
# Test data shape: (200, 8)

# %%
model=RandomForestClassifier(n_estimators=100,random_state=42,n_jobs=-1)

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=['No Failure (0)', 'Failure (1)'])

# %%
print("\n--- Model Evaluation ---")
print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(report)
# Out:
# --- Model Evaluation ---
# Accuracy: 0.9900
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# No Failure (0)       0.99      1.00      0.99       162
#    Failure (1)       1.00      0.95      0.97        38
#
#       accuracy                           0.99       200
#      macro avg       0.99      0.97      0.98       200
#   weighted avg       0.99      0.99      0.99       200

# %%
import joblib

# Save model to a file in Colab
joblib.dump(model, "rf_failure_predictor.pkl")

print("✅ Model saved successfully!")
